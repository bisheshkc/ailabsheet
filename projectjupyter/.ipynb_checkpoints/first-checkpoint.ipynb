# %%
a=int(input("enter the value of a:"))
print(a)
# Out:
# enter the value of a: 23
# 23

# %%
print(3+3)
# Out:
# 6

# %% [markdown]
# numpy

# %%
import numpy as np

# %%
n=np.array([1,2,3,4,5])

# %%
n
# Out:
# array([1, 2, 3, 4, 5])

# %%
print(type(n))
# Out:
# <class 'numpy.ndarray'>

# %%
n1=n*2

# %%
n1
# Out:
# array([ 2,  4,  6,  8, 10])
